# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import warnings
import seaborn as sns 
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('bestsellers_with_categories_2022_03_27.csv')

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.shape
# Out:
# (700, 7)

# %%
df.head()
# Out:
#                                                 Name            Author  \
# 0  Act Like a Lady, Think Like a Man: What Men Re...      Steve Harvey
# 1  Arguing with Idiots: How to Stop Small Minds a...        Glenn Beck
# 2          Breaking Dawn (The Twilight Saga, Book 4)   Stephenie Meyer
# 3        Crazy Love: Overwhelmed by a Relentless God      Francis Chan
# 4  Dead And Gone: A Sookie Stackhouse Novel (Sook...  Charlaine Harris
#
#    User Rating  Reviews  Price  Year        Genre
# 0          4.6     5013     17  2009  Non Fiction
# 1          4.6      798      5  2009  Non Fiction
# 2          4.6     9769     13  2009      Fiction
# 3          4.7     1542     14  2009  Non Fiction
# 4          4.6     1541      4  2009      Fiction

# %%
df.tail()
# Out:
#                                      Name                 Author  User Rating  \
# 695      The Wonderful Things You Will Be  Emily Winfield Martin          4.9
# 696                    Ugly Love: A Novel         Colleen Hoover          4.7
# 697                                Verity         Colleen Hoover          4.6
# 698  What to Expect When You're Expecting          Heidi Murkoff          4.8
# 699               Where the Crawdads Sing            Delia Owens          4.8
#
#      Reviews  Price  Year        Genre
# 695    20920      9  2022      Fiction
# 696    33929     10  2022      Fiction
# 697    71826     11  2022      Fiction
# 698    27052     13  2022  Non Fiction
# 699   208917     10  2022      Fiction

# %%
df.columns
# Out:
# Index(['Name', 'Author', 'User Rating', 'Reviews', 'Price', 'Year', 'Genre'], dtype='object')

# %%
df.columns[0:3]
# Out:
# Index(['Name', 'Author', 'User Rating'], dtype='object')

# %%
df['Name'].dtypes
# Out:
# dtype('O')

# %%
df['Name'].dtypes
df.Reviews.dtypes
# Out:
# dtype('int64')

# %%
df.iloc[0:15]
# Out:
#                                                  Name            Author  \
# 0   Act Like a Lady, Think Like a Man: What Men Re...      Steve Harvey
# 1   Arguing with Idiots: How to Stop Small Minds a...        Glenn Beck
# 2           Breaking Dawn (The Twilight Saga, Book 4)   Stephenie Meyer
# 3         Crazy Love: Overwhelmed by a Relentless God      Francis Chan
# 4   Dead And Gone: A Sookie Stackhouse Novel (Sook...  Charlaine Harris
# 5       Diary of a Wimpy Kid: The Last Straw (Book 3)       Jeff Kinney
# 6   Divine Soul Mind Body Healing and Transmission...      Zhi Gang Sha
# 7   Dog Days (Diary of a Wimpy Kid, Book 4) (Volum...       Jeff Kinney
# 8   Eat This Not That! Supermarket Survival Guide:...   David Zinczenko
# 9   Eat This, Not That! Thousands of Simple Food S...   David Zinczenko
# 10                           Eclipse (Twilight Sagas)   Stephenie Meyer
# 11                                 Eclipse (Twilight)   Stephenie Meyer
# ...

# %%
df.describe()
# Out:
#        User Rating        Reviews       Price         Year
# count   700.000000     700.000000  700.000000   700.000000
# mean      4.639857   19255.195714   12.700000  2015.500000
# std       0.218586   23613.443875    9.915162     4.034011
# min       3.300000      37.000000    0.000000  2009.000000
# 25%       4.500000    4987.250000    7.000000  2012.000000
# 50%       4.700000   10284.000000   11.000000  2015.500000
# 75%       4.800000   23358.000000   15.000000  2019.000000
# max       4.900000  208917.000000  105.000000  2022.000000

# %%
df.Name
# Out:
# 0      Act Like a Lady, Think Like a Man: What Men Re...
# 1      Arguing with Idiots: How to Stop Small Minds a...
# 2              Breaking Dawn (The Twilight Saga, Book 4)
# 3            Crazy Love: Overwhelmed by a Relentless God
# 4      Dead And Gone: A Sookie Stackhouse Novel (Sook...
#                              ...
# 695                     The Wonderful Things You Will Be
# 696                                   Ugly Love: A Novel
# 697                                               Verity
# 698                 What to Expect When You're Expecting
# 699                              Where the Crawdads Sing
# Name: Name, Length: 700, dtype: object

# %%
df.Price.value_counts(ascending = False)
# Out:
# 8      63
# 5      52
# 6      46
# 9      46
# 11     46
# 14     43
# 10     40
# 13     40
# 4      38
# 12     35
# 7      35
# 16     26
# 17     24
# 15     24
# 20     23
# 18     22
# 21     12
# 0      12
# 46     10
# 28      6
# 23      6
# 22      6
# 24      5
# 30      5
# 2       5
# 19      5
# 40      5
# 27      4
# 32      3
# 25      2
# 105     2
# 42      1
# 82      1
# 1       1
# 53      1
# 39      1
# 54      1
# 52      1
# 36      1
# 3       1
# Name: Price, dtype: int64

# %%
df.loc[0:10]
# Out:
#                                                  Name            Author  \
# 0   Act Like a Lady, Think Like a Man: What Men Re...      Steve Harvey
# 1   Arguing with Idiots: How to Stop Small Minds a...        Glenn Beck
# 2           Breaking Dawn (The Twilight Saga, Book 4)   Stephenie Meyer
# 3         Crazy Love: Overwhelmed by a Relentless God      Francis Chan
# 4   Dead And Gone: A Sookie Stackhouse Novel (Sook...  Charlaine Harris
# 5       Diary of a Wimpy Kid: The Last Straw (Book 3)       Jeff Kinney
# 6   Divine Soul Mind Body Healing and Transmission...      Zhi Gang Sha
# 7   Dog Days (Diary of a Wimpy Kid, Book 4) (Volum...       Jeff Kinney
# 8   Eat This Not That! Supermarket Survival Guide:...   David Zinczenko
# 9   Eat This, Not That! Thousands of Simple Food S...   David Zinczenko
# 10                           Eclipse (Twilight Sagas)   Stephenie Meyer
#
#     User Rating  Reviews  Price  Year        Genre
# 0           4.6     5013     17  2009  Non Fiction
# ...

# %%
df.isnull()
# Out:
#       Name  Author  User Rating  Reviews  Price   Year  Genre
# 0    False   False        False    False  False  False  False
# 1    False   False        False    False  False  False  False
# 2    False   False        False    False  False  False  False
# 3    False   False        False    False  False  False  False
# 4    False   False        False    False  False  False  False
# ..     ...     ...          ...      ...    ...    ...    ...
# 695  False   False        False    False  False  False  False
# 696  False   False        False    False  False  False  False
# 697  False   False        False    False  False  False  False
# 698  False   False        False    False  False  False  False
# 699  False   False        False    False  False  False  False
#
# [700 rows x 7 columns]

# %%
df.notnull()
# Out:
#      Name  Author  User Rating  Reviews  Price  Year  Genre
# 0    True    True         True     True   True  True   True
# 1    True    True         True     True   True  True   True
# 2    True    True         True     True   True  True   True
# 3    True    True         True     True   True  True   True
# 4    True    True         True     True   True  True   True
# ..    ...     ...          ...      ...    ...   ...    ...
# 695  True    True         True     True   True  True   True
# 696  True    True         True     True   True  True   True
# 697  True    True         True     True   True  True   True
# 698  True    True         True     True   True  True   True
# 699  True    True         True     True   True  True   True
#
# [700 rows x 7 columns]

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.nunique()
# Out:
# Name           441
# Author         305
# User Rating     14
# Reviews        462
# Price           40
# Year            14
# Genre            2
# dtype: int64

# %%
df.dtypes
# Out:
# Name            object
# Author          object
# User Rating    float64
# Reviews          int64
# Price            int64
# Year             int64
# Genre           object
# dtype: object

# %%
df['Name'] = df['Name'].fillna("No Data Available")

# %%
df=df.drop_duplicates(subset=df.columns[1:], keep='first')

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.Reviews.mean()
# Out:
# 19255.195714285714

# %%
#Comparing two columns

df.loc[['Name', 'Reviews']]
# Out:
#                                                   Name  Reviews
# 0    Act Like a Lady, Think Like a Man: What Men Re...     5013
# 1    Arguing with Idiots: How to Stop Small Minds a...      798
# 2            Breaking Dawn (The Twilight Saga, Book 4)     9769
# 3          Crazy Love: Overwhelmed by a Relentless God     1542
# 4    Dead And Gone: A Sookie Stackhouse Novel (Sook...     1541
# ..                                                 ...      ...
# 695                   The Wonderful Things You Will Be    20920
# 696                                 Ugly Love: A Novel    33929
# 697                                             Verity    71826
# 698               What to Expect When You're Expecting    27052
# 699                            Where the Crawdads Sing   208917
#
# [700 rows x 2 columns]

# %%
df[0:20][['Name', 'User Rating','Reviews']]
# Out:
#                                                  Name  User Rating  Reviews
# 0   Act Like a Lady, Think Like a Man: What Men Re...          4.6     5013
# 1   Arguing with Idiots: How to Stop Small Minds a...          4.6      798
# 2           Breaking Dawn (The Twilight Saga, Book 4)          4.6     9769
# 3         Crazy Love: Overwhelmed by a Relentless God          4.7     1542
# 4   Dead And Gone: A Sookie Stackhouse Novel (Sook...          4.6     1541
# 5       Diary of a Wimpy Kid: The Last Straw (Book 3)          4.8     3837
# 6   Divine Soul Mind Body Healing and Transmission...          4.6       37
# 7   Dog Days (Diary of a Wimpy Kid, Book 4) (Volum...          4.8     3181
# 8   Eat This Not That! Supermarket Survival Guide:...          4.5      720
# 9   Eat This, Not That! Thousands of Simple Food S...          4.3      956
# 10                           Eclipse (Twilight Sagas)          4.7     5505
# ...

# %%
#now using the Diagrammmm to plotttt!!!!!

# %%
df.plot(x='User Rating', y='Reviews', style='o')
plt.xlabel('User Rating')
plt.ylabel('Reviews')
plt.title('Scatter Plot')
plt.show()

# %%
df.plot(x='Price', y='Year', style='o')
# Out:
# <AxesSubplot:xlabel='Price'>

# %%
sns.heatmap(df.corr(), annot=True)
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(13, 8))

sns.boxplot(x="Year", y="Price",
            hue="Genre", palette=["m", "g"],
            data=df)
sns.despine(offset=10, trim=True)

# %%
plt.figure(figsize=(15, 7))
sns.barplot(x='Year', y='Price', hue='Genre', data=df).set(title='Comparision')
# Out:
# [Text(0.5, 1.0, 'Comparision')]

# %%
# !pip install apyori --user
# Out:
# ...
#   Created wheel for apyori: filename=apyori-1.1.2-py3-none-any.whl size=5974 sha256=85c1f7127ea03871f3c47734259e562bd22d700ecf99708d4e5550635f6c425d
#   Stored in directory: c:\users\ravi\appdata\local\pip\cache\wheels\32\2a\54\10c595515f385f3726642b10c60bf788029e8f3a1323e3913a
# Successfully built apyori
# ...
#   WARNING: The script apyori-run.exe is installed in 'C:\Users\Ravi\AppData\Roaming\Python\Python39\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.

# %%
df.drop(['Name','Author','Genre'],axis = 1)
# Out:
#      User Rating  Reviews  Price  Year
# 0            4.6     5013     17  2009
# 1            4.6      798      5  2009
# 2            4.6     9769     13  2009
# 3            4.7     1542     14  2009
# 4            4.6     1541      4  2009
# ..           ...      ...    ...   ...
# 695          4.9    20920      9  2022
# 696          4.7    33929     10  2022
# 697          4.6    71826     11  2022
# 698          4.8    27052     13  2022
# 699          4.8   208917     10  2022
#
# [700 rows x 4 columns]
